# %% [markdown]
# ## Importing all the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv('C:/Users/shubham pal/Downloads/Telco-Customer-Churn.csv',na_values=[' '])

# %%
data.head(51)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data.shape
print('No of records:',data.shape[0])
print('No of Attributes:',data.shape[1])
# Out:
# No of records: 7043
# No of Attributes: 21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
data.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
data.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.016567        0.220173      0.102411
# tenure               0.016567  1.000000        0.247900      0.825880
# MonthlyCharges       0.220173  0.247900        1.000000      0.651065
# TotalCharges         0.102411  0.825880        0.651065      1.000000

# %%
sns.pairplot(data)

# %% [markdown]
# # Missing Value Treatment

# %%
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
np.where(data['tenure']==0)
# Out:
# (array([ 488,  753,  936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754],
#        dtype=int64),)

# %%
np.where(data['TotalCharges']=='')
# Out:
# (array([], dtype=int64),)

# %%
data.drop([488,  753,  936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754],inplace =True )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
#data['TotalCharges']= data['TotalCharges'].astype(float)
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# ## Outrlier Treatment

# %%
sns.scatterplot(x='tenure',y='MonthlyCharges',data=data)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %% [markdown]
# # Feature Selection

# %%
data.head(20)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
del data['customerID']

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# # Feature Engineering

# %%
data = pd.get_dummies(data)

# %%
data.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0              0       1           29.85         29.85              1
# 1              0      34           56.95       1889.50              0
# 2              0       2           53.85        108.15              0
# 3              0      45           42.30       1840.75              0
# 4              0       2           70.70        151.65              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    Contract_One year  Contract_Two year  PaperlessBilling_No  \
# ...

# %%
del data['gender_Female']
del data['Partner_No']
del data['Dependents_No']
del data['PhoneService_No']
del data['PaperlessBilling_No']
del data['Churn_No']

# %%
data.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85            0
# 1              0      34           56.95       1889.50            1
# 2              0       2           53.85        108.15            1
# 3              0      45           42.30       1840.75            1
# 4              0       2           70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  MultipleLines_No  \
# 0            1               0                 0                 0
# 1            0               0                 1                 1
# 2            0               0                 1                 1
# 3            0               0                 0                 0
# 4            0               0                 1                 1
#
#    MultipleLines_No phone service  ...  StreamingMovies_Yes  \
# 0                               1  ...                    0
# ...

# %% [markdown]
# # Train Test Split

# %%
x = data.drop(columns=['Churn_Yes'])
y = data['Churn_Yes']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x,y,train_size=0.8, stratify=y, random_state=2)

# %%
print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# Out:
# (5625, 40) (1407, 40) (5625,) (1407,)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(max_iter=500)

# %%
model_lr.fit(train_x,train_y)
# Out:
# LogisticRegression(max_iter=500)

# %%
# Hard Predictions
pred_y_lr = model_lr.predict(test_x)

# %%
pd.DataFrame({'Actual':test_y,'Predicted':pred_y_lr}).head(20)
# Out:
#       Actual  Predicted
# 6248       0          0
# 5140       0          1
# 2860       0          0
# 1865       0          0
# 995        1          0
# 6126       1          1
# 4747       0          0
# 3575       0          0
# 3968       0          0
# 234        0          0
# 2818       1          0
# 3443       0          0
# 1668       0          0
# 6225       0          0
# 1527       0          0
# 2166       0          0
# 5593       0          0
# 5037       1          1
# 2815       1          0
# 193        0          0

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score

# %%
def validation(actual,pred):
    print('Confusion Matrix\n',confusion_matrix(actual,pred))
    print('\nAccuracy :',accuracy_score(actual,pred))
    print('\nRecall :',recall_score(actual,pred))
    print('\nPrecision :',precision_score(actual,pred))
    print('\nF1 Score :',f1_score(actual,pred))

# %%
validation(test_y,pred_y_lr)
# Out:
# Confusion Matrix
#  [[916 117]
#  [176 198]]
#
# Accuracy : 0.7917555081734187
#
# Recall : 0.5294117647058824
#
# Precision : 0.6285714285714286
#
# F1 Score : 0.5747460087082729

# %%
# roc curve

# %%
from sklearn.metrics import roc_auc_score, roc_curve
auc = roc_auc_score(test_y,pred_y_lr)

# %%
auc
# Out:
# 0.7080747110073458

# %%
# soft predictions

# %%
pred_y_lr_soft = model_lr.predict_proba(test_x)

# %%
pred_y_lr_soft=pred_y_lr_soft[:,1]

# %%
pd.DataFrame({'Actual':test_y,'Hard Pred':pred_y_lr,'Soft Pred':pred_y_lr_soft}).head(20)
# Out:
#       Actual  Hard Pred  Soft Pred
# 6248       0          0   0.030696
# 5140       0          1   0.782141
# 2860       0          0   0.329773
# 1865       0          0   0.448844
# 995        1          0   0.205849
# 6126       1          1   0.591848
# 4747       0          0   0.025789
# 3575       0          0   0.108920
# 3968       0          0   0.003151
# 234        0          0   0.114343
# 2818       1          0   0.248767
# 3443       0          0   0.105126
# 1668       0          0   0.306087
# 6225       0          0   0.038810
# 1527       0          0   0.002570
# 2166       0          0   0.100707
# 5593       0          0   0.050618
# 5037       1          1   0.638518
# 2815       1          0   0.468561
# 193        0          0   0.076535

# %%
fpr,tpr,thrshold = roc_curve(test_y, pred_y_lr_soft)

# %%
roc_df = pd.DataFrame({'TPR':tpr,'FPR':fpr,'Threshold':thrshold})

# %%
roc_df.sort_values(by=['TPR'], ascending=False)
# Out:
#           TPR       FPR  Threshold
# 367  1.000000  1.000000   0.002405
# 366  1.000000  0.872217   0.013744
# 365  0.997326  0.872217   0.013911
# 364  0.997326  0.822846   0.020444
# 363  0.994652  0.822846   0.020556
# ..        ...       ...        ...
# 5    0.066845  0.001936   0.782412
# 2    0.064171  0.000000   0.796189
# 3    0.064171  0.000968   0.789995
# 1    0.002674  0.000000   0.872737
# 0    0.000000  0.000000   1.872737
#
# [368 rows x 3 columns]

# %%
plt.plot(fpr,tpr)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC CURVE')
print('Area Under The Curve :',auc)
plt.show()
# Out:
# Area Under The Curve : 0.7080747110073458

# %%
# Let us change the classifier cutoff

# %%
threshold = 0.45
pred_y_soft_new = (pred_y_lr_soft>=threshold).astype(int)

# %%
pred_y_soft_new
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
pd.DataFrame({'Actual':test_y,'Hard Pred(0.5)':pred_y_lr,'Hard Pred(0.45)':pred_y_soft_new}).head(20)
# Out:
#       Actual  Hard Pred(0.5)  Hard Pred(0.45)
# 6248       0               0                0
# 5140       0               1                1
# 2860       0               0                0
# 1865       0               0                0
# 995        1               0                0
# 6126       1               1                1
# 4747       0               0                0
# 3575       0               0                0
# 3968       0               0                0
# 234        0               0                0
# 2818       1               0                0
# 3443       0               0                0
# 1668       0               0                0
# 6225       0               0                0
# 1527       0               0                0
# 2166       0               0                0
# 5593       0               0                0
# 5037       1               1                1
# 2815       1               0                1
# ...

# %%
validation(test_y,pred_y_soft_new)
# Out:
# Confusion Matrix
#  [[885 148]
#  [152 222]]
#
# Accuracy : 0.7867803837953091
#
# Recall : 0.5935828877005348
#
# Precision : 0.6
#
# F1 Score : 0.5967741935483871

# %% [markdown]
# # Checking the Model for overfitting

# %%
y_train_pred = model_lr.predict(train_x)

# %%
validation(train_y,y_train_pred)  # Train Accuracy
# Out:
# Confusion Matrix
#  [[3739  391]
#  [ 687  808]]
#
# Accuracy : 0.8083555555555556
#
# Recall : 0.5404682274247492
#
# Precision : 0.6738949124270225
#
# F1 Score : 0.5998515219005197

# %%
validation(test_y,pred_y_lr)    # Test Accuracy
# Out:
# Confusion Matrix
#  [[916 117]
#  [176 198]]
#
# Accuracy : 0.7917555081734187
#
# Recall : 0.5294117647058824
#
# Precision : 0.6285714285714286
#
# F1 Score : 0.5747460087082729

# %%
# Here we have Similar test and  train Accuracy so our Model does not Overfit..!

# %% [markdown]
# # NAIVE BAYES MODEL

# %%
print(train_x.shape,train_y.shape,test_x.shape,test_y.shape)
# Out:
# (5625, 40) (5625,) (1407, 40) (1407,)

# %%
from sklearn.naive_bayes import GaussianNB
model_nb = GaussianNB()

# %%
model_nb.fit(train_x,train_y)
# Out:
# GaussianNB()

# %%
y_pred_nb = model_nb.predict(test_x)

# %%
pd.DataFrame({'Actual':test_y,'LR Pred':pred_y_lr,'NB Pred':y_pred_nb}).head(20)
# Out:
#       Actual  LR Pred  NB Pred
# 6248       0        0        0
# 5140       0        1        1
# 2860       0        0        1
# 1865       0        0        1
# 995        1        0        1
# 6126       1        1        1
# 4747       0        0        0
# 3575       0        0        1
# 3968       0        0        0
# 234        0        0        0
# 2818       1        0        1
# 3443       0        0        0
# 1668       0        0        1
# 6225       0        0        0
# 1527       0        0        0
# 2166       0        0        0
# 5593       0        0        0
# 5037       1        1        1
# 2815       1        0        1
# 193        0        0        0

# %%
print('Validation Data for NB Model')
validation(test_y,y_pred_nb)
print('\n\nValidation Data for LR Model')
validation(test_y,pred_y_lr)
# Out:
# Validation Data for NB Model
# Confusion Matrix
#  [[635 398]
#  [ 47 327]]
#
# Accuracy : 0.6837242359630419
#
# Recall : 0.8743315508021391
#
# Precision : 0.4510344827586207
#
# F1 Score : 0.5950864422202001
#
#
# Validation Data for LR Model
# Confusion Matrix
#  [[916 117]
#  [176 198]]
#
# Accuracy : 0.7917555081734187
#
# Recall : 0.5294117647058824
#
# Precision : 0.6285714285714286
#
# F1 Score : 0.5747460087082729

# %%
y_pred_nb_soft = model_nb.predict_proba(test_x)

# %%
y_pred_nb_soft[:,1]
# Out:
# array([1.25603415e-09, 9.99999865e-01, 9.99401761e-01, ...,
#        9.64943526e-01, 1.27870076e-10, 9.22335043e-01])

# %%
pd.DataFrame({'Actual':test_y,'NB Soft Pred':y_pred_nb_soft[:,1],'NB Pred':y_pred_nb}).head(20)
# Out:
#       Actual  NB Soft Pred  NB Pred
# 6248       0  1.256034e-09        0
# 5140       0  9.999999e-01        1
# 2860       0  9.994018e-01        1
# 1865       0  9.986022e-01        1
# 995        1  9.946571e-01        1
# 6126       1  9.999930e-01        1
# 4747       0  3.538388e-22        0
# 3575       0  9.981480e-01        1
# 3968       0  2.043860e-28        0
# 234        0  1.771275e-17        0
# 2818       1  9.818785e-01        1
# 3443       0  3.057989e-03        0
# 1668       0  9.264963e-01        1
# 6225       0  3.297562e-11        0
# 1527       0  4.716126e-29        0
# 2166       0  3.800199e-02        0
# 5593       0  1.031603e-04        0
# 5037       1  9.999987e-01        1
# 2815       1  9.998048e-01        1
# 193        0  1.575907e-10        0

# %%
# Plot the ROC Curve
fpr_nb, tpr_nb, threshold_nb = roc_curve(test_y,y_pred_nb_soft[:,1])

# %%
plt.plot(fpr,tpr, label ='LR')
plt.plot(fpr_nb,tpr_nb, label='NB')
plt.legend()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC CURVE')
print('LR AUC',roc_auc_score(test_y,pred_y_lr))
print('NB AUC',roc_auc_score(test_y,y_pred_nb))
plt.show()
# Out:
# LR AUC 0.7080747110073458
# NB AUC 0.7445229874049417

# %%
threshold = 0.55
pred_nb_new = (y_pred_nb_soft[:,1]>=threshold).astype(int)

# %%
pred_nb_new
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
pd.DataFrame({'Actual':test_y,'NB Pred (0.5)':y_pred_nb,'NB Pred (0.55)':pred_nb_new}).head(20)
# Out:
#       Actual  NB Pred (0.5)  NB Pred (0.55)
# 6248       0              0               0
# 5140       0              1               1
# 2860       0              1               1
# 1865       0              1               1
# 995        1              1               1
# 6126       1              1               1
# 4747       0              0               0
# 3575       0              1               1
# 3968       0              0               0
# 234        0              0               0
# 2818       1              1               1
# 3443       0              0               0
# 1668       0              1               1
# 6225       0              0               0
# 1527       0              0               0
# 2166       0              0               0
# 5593       0              0               0
# 5037       1              1               1
# 2815       1              1               1
# 193        0              0               0

# %%
validation(test_y,pred_nb_new)
# Out:
# Confusion Matrix
#  [[636 397]
#  [ 47 327]]
#
# Accuracy : 0.6844349680170576
#
# Recall : 0.8743315508021391
#
# Precision : 0.4516574585635359
#
# F1 Score : 0.5956284153005464

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

params = {'criterion':['entropy','gini'],
         'max_depth':[2,3,4]}

# %%
gscv = GridSearchCV(estimator=DecisionTreeClassifier(), 
                    param_grid=params,
                   scoring='accuracy',
                    cv=2,
                   verbose=3)

# %%
gscv.fit(train_x,train_y)
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [CV 1/2] END ....criterion=entropy, max_depth=2;, score=0.753 total time=   0.0s
# [CV 2/2] END ....criterion=entropy, max_depth=2;, score=0.751 total time=   0.0s
# [CV 1/2] END ....criterion=entropy, max_depth=3;, score=0.790 total time=   0.0s
# [CV 2/2] END ....criterion=entropy, max_depth=3;, score=0.752 total time=   0.0s
# [CV 1/2] END ....criterion=entropy, max_depth=4;, score=0.790 total time=   0.0s
# [CV 2/2] END ....criterion=entropy, max_depth=4;, score=0.782 total time=   0.0s
# [CV 1/2] END .......criterion=gini, max_depth=2;, score=0.753 total time=   0.0s
# [CV 2/2] END .......criterion=gini, max_depth=2;, score=0.751 total time=   0.0s
# [CV 1/2] END .......criterion=gini, max_depth=3;, score=0.790 total time=   0.0s
# [CV 2/2] END .......criterion=gini, max_depth=3;, score=0.752 total time=   0.0s
# [CV 1/2] END .......criterion=gini, max_depth=4;, score=0.790 total time=   0.0s
# ...

# %%
gscv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 4}

# %%
model_dt = DecisionTreeClassifier(**gscv.best_params_)

# %%
model_dt.fit(train_x,train_y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_pred_dt = model_dt.predict(test_x)

# %%
validation(test_y, y_pred_dt)
# Out:
# Confusion Matrix
#  [[926 107]
#  [191 183]]
#
# Accuracy : 0.7882018479033405
#
# Recall : 0.4893048128342246
#
# Precision : 0.6310344827586207
#
# F1 Score : 0.5512048192771085

# %%
from sklearn import tree
plt.figure(figsize=(23,12))
tree.plot_tree(model_dt, feature_names=train_x.columns)
plt.show()

# %%
y_pred_dt_soft = model_dt.predict_proba(test_x)

# %%
y_pred_dt_soft[:,1]
# Out:
# array([0.01545779, 0.85561497, 0.30612245, ..., 0.31527094, 0.01545779,
#        0.143951  ])

# %%
# PLOT the ROC AUC curve

fpr_dt, tpr_dt, threshold_dt = roc_curve(test_y,y_pred_dt_soft[:,1])

# %%
plt.plot(fpr,tpr, label ='LR')
plt.plot(fpr_nb,tpr_nb, label='NB')
plt.plot(fpr_dt,tpr_dt, label='DT')
plt.legend()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC CURVE')
print('LR AUC',roc_auc_score(test_y,pred_y_lr),'LR Model Score',model_lr.score(train_x,train_y))
print('NB AUC',roc_auc_score(test_y,y_pred_nb),'NB Model Score',model_nb.score(train_x,train_y))
print('DT AUC',roc_auc_score(test_y,y_pred_dt),'DT Model Score',model_dt.score(train_x,train_y))
plt.show()
# Out:
# LR AUC 0.7080747110073458 LR Model Score 0.8083555555555556
# NB AUC 0.7445229874049417 NB Model Score 0.6878222222222222
# DT AUC 0.6928615061266961 DT Model Score 0.7975111111111111

# %% [markdown]
# # Random Forest (Ensemble Model - Bagging)

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
params = {'n_estimators':[80,100,120,130],
         'max_depth':[2,3,4,5],
         'criterion':['entropy']}


gscv = GridSearchCV(estimator=RandomForestClassifier(),
                   param_grid= params,
                   scoring='accuracy',
                   verbose=1)

# %%
gscv.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['entropy'], 'max_depth': [2, 3, 4, 5],
#                          'n_estimators': [80, 100, 120, 130]},
#              scoring='accuracy', verbose=1)

# %%
gscv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 80}

# %%
model_rf = RandomForestClassifier(**gscv.best_params_)

# %%
model_rf.fit(train_x,train_y)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, n_estimators=80)

# %%
y_pred_rf = model_rf.predict(test_x)

# %%
validation(test_y,y_pred_rf)
# Out:
# Confusion Matrix
#  [[957  76]
#  [211 163]]
#
# Accuracy : 0.7960199004975125
#
# Recall : 0.4358288770053476
#
# Precision : 0.6820083682008368
#
# F1 Score : 0.531810766721044

# %%
y_pred_rf_soft = model_rf.predict_proba(test_x)

# %%
fpr_rf, tpr_rf, threshold_rf = roc_curve(test_y,y_pred_rf_soft[:,1])

# %%
#plt.plot(fpr,tpr, label ='LR')
#plt.plot(fpr_nb,tpr_nb, label='NB')
plt.plot(fpr_dt,tpr_dt, label='DT')
plt.plot(fpr_rf,tpr_rf, label='RF')
plt.legend()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC CURVE')
print('LR AUC',roc_auc_score(test_y,pred_y_lr),'LR Model Score',model_lr.score(test_x,test_y))
print('NB AUC',roc_auc_score(test_y,y_pred_nb),'NB Model Score',model_nb.score(test_x,test_y))
print('DT AUC',roc_auc_score(test_y,y_pred_dt),'DT Model Score',model_dt.score(test_x,test_y))
print('RF AUC',roc_auc_score(test_y,y_pred_rf),'RF Model Score',model_rf.score(test_x,test_y))
plt.show()
# Out:
# LR AUC 0.7080747110073458 LR Model Score 0.7917555081734187
# NB AUC 0.7445229874049417 NB Model Score 0.6837242359630419
# DT AUC 0.6928615061266961 DT Model Score 0.7882018479033405
# RF AUC 0.6811283784833128 RF Model Score 0.7960199004975125

# %% [markdown]
# # Ensemble Model (Boosting)

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
params = {'n_estimators':[120,130,140,150]}

# %%
# Ada boost

# %%
ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2))
gscv_ada = GridSearchCV(estimator=ada,
                       param_grid=params,
                       scoring='accuracy',
                       verbose=1)

# %%
gscv_ada.fit(x,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2)),
#              param_grid={'n_estimators': [120, 130, 140, 150]},
#              scoring='accuracy', verbose=1)

# %%
gscv_ada.best_params_
# Out:
# {'n_estimators': 140}

# %%
model_ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=3),n_estimators=120)

# %%
model_ada.fit(train_x,train_y)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3),
#                    n_estimators=120)

# %%
y_pred_ad = model_ada.predict(test_x)

# %%
validation(test_y,y_pred_ad)
# Out:
# Confusion Matrix
#  [[900 133]
#  [185 189]]
#
# Accuracy : 0.7739872068230277
#
# Recall : 0.5053475935828877
#
# Precision : 0.5869565217391305
#
# F1 Score : 0.5431034482758621

# %%
model_ada.score(test_x,test_y)
# Out:
# 0.7739872068230277

# %%
# Gradient Boosting
params = {'learning_rate':[0.01,0.1,1],
         'n_estimators':[90,100,120,130],
         'max_depth':[2,3]}

# %%
gscv_gb = GridSearchCV(estimator=GradientBoostingClassifier(),
                       param_grid= params,
                       scoring='accuracy',
                       cv= 2,
                       verbose=1)

# %%
gscv_gb.fit(x,y)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# GridSearchCV(cv=2, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 1], 'max_depth': [2, 3],
#                          'n_estimators': [90, 100, 120, 130]},
#              scoring='accuracy', verbose=1)

# %%
gscv_gb.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100}

# %%
model_gb = GradientBoostingClassifier(**gscv_gb.best_params_)

# %%
model_gb.fit(train_x,train_y)
# Out:
# GradientBoostingClassifier(max_depth=2)

# %%
y_pred_gb = model_gb.predict(test_x)

# %%
validation(test_y,y_pred_gb)
# Out:
# Confusion Matrix
#  [[923 110]
#  [180 194]]
#
# Accuracy : 0.7938877043354655
#
# Recall : 0.5187165775401069
#
# Precision : 0.6381578947368421
#
# F1 Score : 0.5722713864306785

# %%
 model_gb.score(test_x,test_y)
# Out:
# 0.7938877043354655

# %%
# XG Boost

# %%
# pip install xgboost
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
gscv_xgb = GridSearchCV(estimator=xgb,
                       param_grid=params,
                       cv= 2,
                       verbose=1)

# %%
gscv_xgb.fit(x,y)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# [17:16:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
gscv_xgb.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 90}

# %%
modedl_xgb = XGBClassifier(**gscv_xgb.best_params_)

# %%
modedl_xgb.fit(train_x, train_y)
# Out:
# [17:16:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=90, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_xgb = modedl_xgb.predict(test_x)

# %%
validation(test_y,y_pred_xgb)
# Out:
# Confusion Matrix
#  [[923 110]
#  [185 189]]
#
# Accuracy : 0.7903340440653873
#
# Recall : 0.5053475935828877
#
# Precision : 0.6321070234113713
#
# F1 Score : 0.5616641901931649

# %% [markdown]
# # ALL MODELS ACCURACY COMPARISION

# %%
data = {
    'Logistic Regression':[accuracy_score(test_y,pred_y_lr)*100,recall_score(test_y,pred_y_lr)*100,precision_score(test_y,pred_y_lr)*100,f1_score(test_y,pred_y_lr)*100],
    'Naive Bayes':[accuracy_score(test_y,y_pred_nb)*100,recall_score(test_y,y_pred_nb)*100,precision_score(test_y,y_pred_nb)*100,f1_score(test_y,y_pred_nb)*100],
    'DECISION TREE':[accuracy_score(test_y, y_pred_dt)*100,recall_score(test_y, y_pred_dt)*100,precision_score(test_y, y_pred_dt)*100,f1_score(test_y, y_pred_dt)*100],
    'Random Forest (Ensemble Model - Bagging)':[accuracy_score(test_y,y_pred_rf)*100,recall_score(test_y,y_pred_rf)*100,precision_score(test_y,y_pred_rf)*100,f1_score(test_y,y_pred_rf)*100],
    'Ada boost':[accuracy_score(test_y,y_pred_ad)*100,recall_score(test_y,y_pred_ad)*100,precision_score(test_y,y_pred_ad)*100,f1_score(test_y,y_pred_ad)*100],
    'Gradient Boosting':[accuracy_score(test_y,y_pred_gb)*100,recall_score(test_y,y_pred_gb)*100,precision_score(test_y,y_pred_gb)*100,f1_score(test_y,y_pred_gb)*100],
    'XG boost':[accuracy_score(test_y,y_pred_xgb)*100,recall_score(test_y,y_pred_xgb)*100,precision_score(test_y,y_pred_xgb)*100,f1_score(test_y,y_pred_xgb)*100]
}

pd.DataFrame(data,index= ['Accuracy %','Recall %','Precision %','F1 Score %'])
# Out:
#              Logistic Regression  Naive Bayes  DECISION TREE  \
# Accuracy %             79.175551    68.372424      78.820185
# Recall %               52.941176    87.433155      48.930481
# Precision %            62.857143    45.103448      63.103448
# F1 Score %             57.474601    59.508644      55.120482
#
#              Random Forest (Ensemble Model - Bagging)  Ada boost  \
# Accuracy %                                  79.601990  77.398721
# Recall %                                    43.582888  50.534759
# Precision %                                 68.200837  58.695652
# F1 Score %                                  53.181077  54.310345
#
#              Gradient Boosting   XG boost
# Accuracy %           79.388770  79.033404
# Recall %             51.871658  50.534759
# Precision %          63.815789  63.210702
# F1 Score %           57.227139  56.166419

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### In this problem Statement RANDON FOREST gives best accuracy results with accuracy of 79.81 %,
# ### so Random forest can be used for Prediction.
